# %%
import pandas as pd

# %%
df = pd.read_csv(r'D:\PROJECTs\IPL predictor\archive\deliveries.csv')
df
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
df.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batter                   0
# bowler                   0
# non_striker              0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# extras_type         246795
# is_wicket                0
# player_dismissed    247970
# dismissal_kind      247970
# fielder             251566
# dtype: int64

# %%
df.drop(['player_dismissed', 'dismissal_kind', 'fielder', "extras_type", 'match_id'], axis=1, inplace=True)

# %%
df
# Out:
#         inning           batting_team                 bowling_team  over  \
# 0            1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1            1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2            1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3            1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4            1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# ...        ...                    ...                          ...   ...
# 260915       2  Kolkata Knight Riders          Sunrisers Hyderabad     9
# 260916       2  Kolkata Knight Riders          Sunrisers Hyderabad     9
# 260917       2  Kolkata Knight Riders          Sunrisers Hyderabad    10
# 260918       2  Kolkata Knight Riders          Sunrisers Hyderabad    10
# 260919       2  Kolkata Knight Riders          Sunrisers Hyderabad    10
#
#         ball       batter         bowler  non_striker  batsman_runs  \
# ...

# %%
df.isnull().sum()
# Out:
# inning          0
# batting_team    0
# bowling_team    0
# over            0
# ball            0
# batter          0
# bowler          0
# non_striker     0
# batsman_runs    0
# extra_runs      0
# total_runs      0
# is_wicket       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 633

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#         inning           batting_team                 bowling_team  over  \
# 0            1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1            1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2            1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3            1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4            1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# ...        ...                    ...                          ...   ...
# 260915       2  Kolkata Knight Riders          Sunrisers Hyderabad     9
# 260916       2  Kolkata Knight Riders          Sunrisers Hyderabad     9
# 260917       2  Kolkata Knight Riders          Sunrisers Hyderabad    10
# 260918       2  Kolkata Knight Riders          Sunrisers Hyderabad    10
# 260919       2  Kolkata Knight Riders          Sunrisers Hyderabad    10
#
#         ball       batter         bowler  non_striker  batsman_runs  \
# ...

# %%
# spliting into catagorical and numerical data 
catagorical = df.select_dtypes(include=['O'])
numerical = df.select_dtypes(exclude=['O'])
catagorical
# Out:
#                  batting_team                 bowling_team       batter  \
# 0       Kolkata Knight Riders  Royal Challengers Bangalore   SC Ganguly
# 1       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 2       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 3       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 4       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# ...                       ...                          ...          ...
# 260915  Kolkata Knight Riders          Sunrisers Hyderabad      SS Iyer
# 260916  Kolkata Knight Riders          Sunrisers Hyderabad      VR Iyer
# 260917  Kolkata Knight Riders          Sunrisers Hyderabad      VR Iyer
# 260918  Kolkata Knight Riders          Sunrisers Hyderabad      SS Iyer
# 260919  Kolkata Knight Riders          Sunrisers Hyderabad      VR Iyer
#
#                bowler  non_striker
# 0             P Kumar  BB McCullum
# ...

# %%
numerical
# Out:
#         inning  over  ball  batsman_runs  extra_runs  total_runs  is_wicket
# 0            1     0     1             0           1           1          0
# 1            1     0     2             0           0           0          0
# 2            1     0     3             0           1           1          0
# 3            1     0     4             0           0           0          0
# 4            1     0     5             0           0           0          0
# ...        ...   ...   ...           ...         ...         ...        ...
# 260915       2     9     5             1           0           1          0
# 260916       2     9     6             1           0           1          0
# 260917       2    10     1             1           0           1          0
# 260918       2    10     2             1           0           1          0
# 260919       2    10     3             1           0           1          0
#
# [260287 rows x 7 columns]
